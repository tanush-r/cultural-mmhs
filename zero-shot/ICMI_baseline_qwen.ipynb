# %% [markdown]
# # Testing

# %%
test_prompt = """
Analyze this image. Does it contain hateful content?

Categories:
- homophobic: anti-gay/lesbian hate
- transphobic: anti-transgender hate
- misogynistic: anti-women hate
- none: neutral, unrelated, or no hateful content present

Describe the image and provide which category it belongs to
"""

# %%
import os
from huggingface_hub import InferenceClient

client = InferenceClient(
    api_key=os.environ["HF_TOKEN"],
)

completion = client.chat.completions.create(
    model="Qwen/Qwen2.5-VL-7B-Instruct:hyperbolic",
    messages=[
        {
            "role": "user",
            "content": [
                {
                    "type": "text",
                    "text": test_prompt
                },
                {
                    "type": "image_url",
                    "image_url": {
                        "url": "https://drive.google.com/uc?export=download&id=1W9OvSWj4hqSaMyzihQnADw59Zu4Vxw-c"
                    }
                }
            ]
        }
    ],
)

print(completion.choices[0].message)
# Out:
# ChatCompletionOutputMessage(role='assistant', content='The image appears to be a screenshot from a concept video titled "The Gap" by the Irugapatru team. It features two individuals in a staged setting, with one person speaking and the other listening. In the background, there are two other individuals seated on chairs, appearing to be part of the audience or a different scene altogether.\n\nAt the bottom of the image, there is a caption in what seems to be Tamil that translates to: "Idhe mari Avanga Bf/Gf kuda indha game aadravanuku life time settlement ra 😂". This translates to "I will marry my BF/GF in this game and end life time settlement 😂". \n\nThe content of the image does not appear to contain any explicit or implicit hateful content related to homophobia, transphobia, or misogyny. It seems to be a humorous statement about marriage and relationships, presented in a light-hearted manner.\n\nTherefore, the category that this image belongs to is:\n\n- none: neutral, unrelated, or no hateful content present.', reasoning=None, tool_call_id=None, tool_calls=[], reasoning_content=None)

# %% [markdown]
# # Tamil

# %%
prompt = """Analyze this image. Does it contain hateful content?

Categories:
- homophobic: anti-gay/lesbian hate
- transphobic: anti-transgender hate
- misogynistic: anti-women hate
- NA: neutral, unrelated, or no hateful content present

Answer only with the category name.
"""

def classify_image(file_id):

    completion = client.chat.completions.create(
        model="Qwen/Qwen2.5-VL-7B-Instruct:hyperbolic",
        messages=[
            {
                "role": "user",
                "content": [
                    {
                        "type": "text",
                        "text": prompt
                    },
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": f"https://drive.google.com/uc?export=download&id={file_id}"
                        }
                    }
                ]
            }
        ],
    )

    return completion.choices[0].message.content

# %%
import json

with open("misogyny/tamil/misogyny_tamil_drive.json", "r") as f:
    files = json.load(f)

# %%
import time

rows = []
BATCH_SIZE = 40
WAIT_SECONDS = 60

for batch_start in range(0, len(files), BATCH_SIZE):
    batch = files[batch_start:batch_start + BATCH_SIZE]
    batch_num = (batch_start // BATCH_SIZE) + 1

    print(f"\n--- Batch {batch_num} ({batch_start+1} to {batch_start+len(batch)}) ---")

    for i, f in enumerate(batch, start=batch_start + 1):
        file_id = f["id"]
        print(f"[{i}/{len(files)}] Processing {f['name']}.jpg ...", end=" ", flush=True)
        try:
            label = classify_image(file_id)
        except Exception as e:
            label = f"ERROR: {e}"
        print(label)
        rows.append({"image_id": f["name"], "labels": label})
        time.sleep(2)

    # Wait between batches, but not after the last one
    if batch_start + BATCH_SIZE < len(files):
        print(f"\nBatch {batch_num} done. Waiting {WAIT_SECONDS}s before next batch...")
        time.sleep(WAIT_SECONDS)
(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["image_id", "labels"])
    writer.writeheader()
    writer.writerows(rows)

print(f"\nDone! Saved {len(rows)} rows → {OUTPUT_CSV}")
# Out:
# Done! Saved 356 rows → misogyny/tamil/test_pred_qwen_tamil.csv

# %% [markdown]
# # Malayalam

# %%
with open("misogyny/malayalam/misogyny_malayalam_drive.json", "r") as f:
    files = json.load(f)

# %%
len(files)
# Out:
# 200

# %%
rows = []
BATCH_SIZE = 40
WAIT_SECONDS = 60

for batch_start in range(0, len(files), BATCH_SIZE):
    batch = files[batch_start:batch_start + BATCH_SIZE]
    batch_num = (batch_start // BATCH_SIZE) + 1

    print(f"\n--- Batch {batch_num} ({batch_start+1} to {batch_start+len(batch)}) ---")

    for i, f in enumerate(batch, start=batch_start + 1):
        file_id = f["id"]
        print(f"[{i}/{len(files)}] Processing {f['name']}.jpg ...", end=" ", flush=True)
        try:
            label = classify_image(file_id)
        except Exception as e:
            label = f"ERROR: {e}"
        print(label)
        rows.append({"image_id": f["name"], "labels": label})
        time.sleep(2)

    # Wait between batches, but not after the last one
    if batch_start + BATCH_SIZE < len(files):
        print(f"\nBatch {batch_num} done. Waiting {WAIT_SECONDS}s before next batch...")
        time.sleep(WAIT_SECONDS)
# Out:
# --- Batch 1 (1 to 40) ---
# [1/200] Processing 79.jpg ... NA
# [2/200] Processing 614.jpg ... NA
# [3/200] Processing 209.jpg ... NA
# [4/200] Processing 333.jpg ... NA
# [5/200] Processing 409.jpg ... NA
# [6/200] Processing 214.jpg ... NA
# [7/200] Processing 200.jpg ... NA
# [8/200] Processing 657.jpg ... NA
# [9/200] Processing 830.jpg ... NA
# [10/200] Processing 949.jpg ... NA
# [11/200] Processing 750.jpg ... NA
# [12/200] Processing 943.jpg ... NA
# [13/200] Processing 366.jpg ... NA
# [14/200] Processing 356.jpg ... NA
# [15/200] Processing 138.jpg ... NA
# [16/200] Processing 846.jpg ... NA
# [17/200] Processing 527.jpg ... NA
# [18/200] Processing 378.jpg ... NA
# [19/200] Processing 671.jpg ... NA
# [20/200] Processing 495.jpg ... NA
# [21/200] Processing 678.jpg ... NA
# [22/200] Processing 803.jpg ... NA
# [23/200] Processing 260.jpg ... NA
# [24/200] Processing 255.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad7405-5c0e4cee663def9c7237af9b;9ee5cc1a-773b-4b65-a7f3-7be69d3ef992)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [25/200] Processing 364.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad7407-7ef279ee32d05a8900a460d0;de33e953-f891-48c9-8663-1f3cb20d93a0)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [26/200] Processing 487.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad740a-37da74fb5d4e3a04597361d6;b2a2ef0b-0709-4232-8eb8-6635e6eeed9d)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [27/200] Processing 990.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad740c-53f5fc527607bddf3b82b0e5;76273a5c-bb88-4d80-b223-3ee36ba31d5b)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [28/200] Processing 111.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad740e-482fe5944dfc30207717edee;4667a7d7-133b-4ccb-b5fb-bdb39d4953a2)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [29/200] Processing 480.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad7410-0c08ebec08dc9c572d6249b2;320bd956-43ca-430c-9064-53701e8eabca)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [30/200] Processing 362.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad7412-326854797f2ea7711d05387a;b34e7f5a-63fc-4a4a-9714-314749f3aabf)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
# [31/200] Processing 311.jpg ... ERROR: Client error '402 Payment Required' for url 'https://router.huggingface.co/v1/chat/completions' (Request ID: Root=1-69ad7414-5bf083b4608b174506005cc2;969bbce2-7156-4fc2-88dd-0c7799d5d936)
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/402
#
# You have depleted your monthly included credits. Purchase pre-paid credits to continue using Inference Providers. Alternatively, subscribe to PRO to get 20x more included usage.
#
# [160/200] Processing 329.jpg ... NA
#
# Batch 4 done. Waiting 60s before next batch...
#
# --- Batch 5 (161 to 200) ---
# [161/200] Processing 60.jpg ... NA
# [162/200] Processing 585.jpg ... NA
# [163/200] Processing 902.jpg ... NA
# [164/200] Processing 199.jpg ... NA
# [165/200] Processing 688.jpg ... NA
# [166/200] Processing 371.jpg ... NA
# [167/200] Processing 622.jpg ... NA
# [168/200] Processing 500.jpg ... NA
# [169/200] Processing 140.jpg ... NA
# [170/200] Processing 347.jpg ... NA
# [171/200] Processing 903.jpg ... NA
# [172/200] Processing 948.jpg ... NA
# [173/200] Processing 987.jpg ... NA
# [174/200] Processing 102.jpg ... NA
# [175/200] Processing 528.jpg ... NA
# [176/200] Processing 236.jpg ... NA
# [177/200] Processing 211.jpg ... NA
# [178/200] Processing 372.jpg ... NA
# [179/200] Processing 320.jpg ... NA
# [180/200] Processing 550.jpg ... NA
# [181/200] Processing 175.jpg ... NA
# [182/200] Processing 762.jpg ... NA
# [183/200] Processing 281.jpg ... NA
# [184/200] Processing 884.jpg ... NA
# [185/200] Processing 974.jpg ... NA
# [186/200] Processing 900.jpg ... NA
# [187/200] Processing 939.jpg ... NA
# [188/200] Processing 77.jpg ... NA
# [189/200] Processing 812.jpg ... NA
# [190/200] Processing 137.jpg ... NA
# [191/200] Processing 637.jpg ... NA
# [192/200] Processing 514.jpg ... NA
# [193/200] Processing 860.jpg ... NA
# [194/200] Processing 627.jpg ... NA
# [195/200] Processing 412.jpg ... NA
# [196/200] Processing 679.jpg ... NA
# [197/200] Processing 741.jpg ... NA
# [198/200] Processing 738.jpg ... NA
# [199/200] Processing 661.jpg ... NA
# [200/200] Processing 522.jpg ... NA

# %%
correct_rows = [row for row in rows if not row["labels"].startswith("ERROR:")]

len(correct_rows)
# Out:
# 143

# %%
OUTPUT_CSV = "misogyny/malayalam/test_pred_qwen_malayalam.csv"
with open(OUTPUT_CSV, "w", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["image_id", "labels"])
    writer.writeheader()
    writer.writerows(correct_rows)

print(f"\nDone! Saved {len(correct_rows)} rows → {OUTPUT_CSV}")
# Out:
# Done! Saved 143 rows → misogyny/malayalam/test_pred_qwen_malayalam.csv

# %%
# Build a set of image_ids that need reprocessing
error_ids = {r["image_id"] for r in rows if str(r["labels"]).startswith("ERROR:")}

# Filter files to only those with errors
retry_files = [f for f in files if f["name"] in error_ids]

new_rows = []

print(f"Retrying {len(retry_files)} failed images...")

BATCH_SIZE = 40
WAIT_SECONDS = 60

for batch_start in range(0, len(retry_files), BATCH_SIZE):
    batch = retry_files[batch_start:batch_start + BATCH_SIZE]
    batch_num = (batch_start // BATCH_SIZE) + 1

    print(f"\n--- Batch {batch_num} ({batch_start+1} to {batch_start+len(batch)}) ---")

    for i, f in enumerate(batch, start=batch_start + 1):
        file_id = f["id"]
        print(f"[{i}/{len(retry_files)}] Processing {f['name']}.jpg ...", end=" ", flush=True)
        try:
            label = classify_image(file_id)
        except Exception as e:
            label = f"ERROR: {e}"
        print(label)

        # Update existing row instead of appending a new one
        for r in rows:
            if r["image_id"] == f["name"]:
                r["labels"] = label
                break

        time.sleep(2)

    if batch_start + BATCH_SIZE < len(retry_files):
        print(f"\nBatch {batch_num} done. Waiting {WAIT_SECONDS}s before next batch...")
        time.sleep(WAIT_SECONDS)

print(f"\nDone. {sum(1 for r in rows if str(r['labels']).startswith('ERROR:'))} errors remaining.")
# Out:
# Retrying 57 failed images...
#
# --- Batch 1 (1 to 40) ---
# [1/57] Processing 255.jpg ... NA
# [2/57] Processing 364.jpg ... NA
# [3/57] Processing 487.jpg ... NA
# [4/57] Processing 990.jpg ... NA
# [5/57] Processing 111.jpg ... NA
# [6/57] Processing 480.jpg ... NA
# [7/57] Processing 362.jpg ... NA
# [8/57] Processing 311.jpg ... NA
# [9/57] Processing 315.jpg ... NA
# [10/57] Processing 690.jpg ... NA
# [11/57] Processing 299.jpg ... NA
# [12/57] Processing 669.jpg ... NA
# [13/57] Processing 866.jpg ... NA
# [14/57] Processing 651.jpg ... NA
# [15/57] Processing 650.jpg ... NA
# [16/57] Processing 768.jpg ... NA
# [17/57] Processing 596.jpg ... NA
# [18/57] Processing 885.jpg ... NA
# [19/57] Processing 61.jpg ... NA
# [20/57] Processing 698.jpg ... NA
# [21/57] Processing 310.jpg ... NA
# [22/57] Processing 463.jpg ... NA
# [23/57] Processing 942.jpg ... NA
# [24/57] Processing 430.jpg ... NA
# [25/57] Processing 978.jpg ... NA
# [26/57] Processing 159.jpg ... NA
# [27/57] Processing 644.jpg ... NA
# [28/57] Processing 322.jpg ... NA
# [29/57] Processing 823.jpg ... NA
# [30/57] Processing 245.jpg ... NA
# [31/57] Processing 811.jpg ... NA
# [32/57] Processing 915.jpg ... NA
# [33/57] Processing 894.jpg ... NA
# [34/57] Processing 282.jpg ... NA
# [35/57] Processing 722.jpg ... NA
# [36/57] Processing 248.jpg ... NA
# [37/57] Processing 45.jpg ... NA
# [38/57] Processing 73.jpg ... NA
# [39/57] Processing 26.jpg ... NA
# [40/57] Processing 216.jpg ... NA
#
# Batch 1 done. Waiting 60s before next batch...
#
# --- Batch 2 (41 to 57) ---
# [41/57] Processing 121.jpg ... NA
# [42/57] Processing 56.jpg ... NA
# [43/57] Processing 530.jpg ... NA
# [44/57] Processing 996.jpg ... NA
# [45/57] Processing 266.jpg ... NA
# [46/57] Processing 850.jpg ... NA
# [47/57] Processing 600.jpg ... NA
# [48/57] Processing 801.jpg ... NA
# [49/57] Processing 868.jpg ... NA
# [50/57] Processing 446.jpg ... NA
# [51/57] Processing 584.jpg ... NA
# [52/57] Processing 560.jpg ... NA
# [53/57] Processing 238.jpg ... NA
# [54/57] Processing 261.jpg ... NA
# [55/57] Processing 714.jpg ... NA
# [56/57] Processing 426.jpg ... NA
# [57/57] Processing 893.jpg ... NA
#
# Done. 0 errors remaining.

# %%
OUTPUT_CSV = "misogyny/malayalam/test_pred_qwen_malayalam.csv"
with open(OUTPUT_CSV, "a", newline="", encoding="utf-8") as f:
    writer = csv.DictWriter(f, fieldnames=["image_id", "labels"])
    writer.writeheader()
    writer.writerows(rows)

print(f"\nDone! Saved {len(rows)} rows → {OUTPUT_CSV}")
# Out:
# Done! Saved 200 rows → misogyny/malayalam/test_pred_qwen_malayalam.csv
